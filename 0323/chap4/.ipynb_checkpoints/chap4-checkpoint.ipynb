# %% [markdown]
# 30. 形態素解析結果の読み込み
# 形態素解析結果（neko.txt.mecab）を読み込むプログラムを実装せよ．ただし，各形態素は表層形（surface），基本形（base），品詞（pos），品詞細分類1（pos1）をキーとするマッピング型に格納し，1文を形態素（マッピング型）のリストとして表現せよ．第4章の残りの問題では，ここで作ったプログラムを活用せよ．

# %%
import pandas as pd

df = pd.read_csv("neko.txt.mecab", sep="\t", header=None)
tdf = df[1].str.split(",", expand=True)
data = pd.concat([df[0], tdf], axis=1)
data.columns = ["surface", "pos", "pos1", "pos2", "pos3", "base", "app_type", "cunjugation", "proto", "reading"]
data = data.loc[~data.surface.isin(["\u3000", "EOS"])]

keys = ["surface", "base", "pos", "pos1"]
dic = {}

for key in keys:
    dic[key] = list(data[key].values)

dic
# Out:
# {'surface': ['一',
#   '吾輩',
#   'は',
#   '猫',
#   'で',
#   'ある',
#   '。',
#   '名前',
#   'は',
#   'まだ',
#   '無い',
#   '。',
#   'どこ',
#   'で',
#   '生れ',
#   'た',
#   'か',
#   'とんと',
#   '見当',
#   'が',
#   'つか',
#   'ぬ',
#   '。',
#   '何',
#   'でも',
#   '薄暗い',
#   'じめじめ',
#   'し',
#   'た',
#   '所',
#   'で',
#   'ニャーニャー',
#   '泣い',
#   'て',
#   'いた事',
#   'だけ',
#   'は',
#   '記憶',
#   'し',
#   'て',
#   'いる',
#   '。',
#   '吾輩',
#   'は',
#   'ここ',
#   'で',
#   '始め',
#   'て',
#   '人間',
#   'という',
#   'もの',
#   'を',
#   '見',
#   'た',
#   '。',
#   'しかも',
#   'あと',
#   'で',
#   '聞く',
#   'と',
#   'それ',
#   'は',
#   '書生',
#   'という',
#   '人間',
#   '中',
#   'で',
#   '一番',
#   '獰悪',
#   'な',
#   '種族',
#   'で',
#   'あっ',
#   'た',
#   'そう',
#   'だ',
#   '。',
#   'この',
#   '書生',
#   'という',
#   'の',
#   'は',
#   '時々',
#   '我々',
#   'を',
#   '捕え',
#   'て',
#   '煮',
#   'て',
#   '食う',
#   'という',
#   '話',
#   'で',
#   'ある',
#   '。',
#   'しかし',
#   'その',
#   '当時',
#   'は',
#   '何',
#   'という',
#   '考',
#   'も',
#   'なかっ',
#   'た',
#   'から',
#   '別段',
#   '恐し',
#   'いとも',
#   '思わ',
#   'なかっ',
#   'た',
#   '。',
#   'ただ',
#   '彼',
#   'の',
#   '掌',
#   'に',
#   '載せ',
#   'られ',
#   'て',
#   'スー',
#   'と',
#   '持ち上げ',
#   'られ',
#   'た',
#   '時',
#   '何だか',
#   'フワフワ',
#   'し',
#   'た',
#   '感じ',
#   'が',
#   'あっ',
#   'た',
#   'ばかり',
#   'で',
#   'ある',
#   '。',
#   '掌',
#   'の',
#   '上',
#   'で',
#   '少し',
#   '落ちつい',
#   'て',
#   '書生',
#   'の',
#   '顔',
#   'を',
#   '見',
#   'た',
#   'の',
#   'が',
#   'いわゆる',
#   '人間',
#   'という',
#   'もの',
#   'の',
#   '見',
#   '始',
#   'で',
#   'あろ',
#   'う',
#   '。',
#   'この',
#   '時',
#   '妙',
#   'な',
#   'もの',
#   'だ',
#   'と',
#   '思っ',
#   'た',
#   '感じ',
#   'が',
#   '今',
#   'でも',
#   '残っ',
#   'て',
#   'いる',
#   '。',
#   '第',
#   '一',
#   '毛',
#   'をもって',
#   '装飾',
#   'さ',
#   'れ',
#   'べき',
#   'はず',
#   'の',
#   '顔',
#   'が',
#   'つるつる',
#   'し',
#   'て',
#   'まるで',
#   '薬缶',
#   'だ',
#   '。',
#   'その後',
#   '猫',
#   'に',
#   'も',
#   'だいぶ',
#   '逢っ',
#   'た',
#   'が',
#   'こんな',
#   '片',
#   '輪',
#   'に',
#   'は',
#   '一',
#   '度',
#   'も',
#   '出会わ',
#   'し',
#   'た',
#   '事',
#   'が',
#   'ない',
#   '。',
#   'のみ',
#   'なら',
#   'ず',
#   '顔',
#   'の',
#   '真中',
#   'が',
#   'あまりに',
#   '突起',
#   'し',
#   'て',
#   'いる',
#   '。',
#   'そうして',
#   'その',
#   '穴',
#   'の',
#   '中',
#   'から',
#   '時々',
#   'ぷうぷうと',
#   '煙',
#   'を',
#   '吹く',
#   '。',
#   'どうも',
#   '咽',
#   'せ',
#   'ぽく',
#   'て',
#   '実に',
#   '弱っ',
#   'た',
#   '。',
#   'これ',
#   'が',
#   '人間',
#   'の',
#   '飲む',
#   '煙草',
#   'という',
#   'もの',
#   'で',
#   'ある',
#   '事',
#   'は',
#   'ようやく',
#   'この',
#   '頃',
#   '知っ',
#   'た',
#   '。',
#   'この',
#   '書生',
#   'の',
#   '掌',
#   'の',
#   '裏',
#   'で',
#   'しばらく',
#   'は',
#   'よい',
#   '心持',
#   'に',
#   '坐っ',
#   'て',
#   'おっ',
#   'た',
#   'が',
#   '、',
#   'しばらく',
#   'する',
#   'と',
#   '非常',
#   'な',
#   '速力',
#   'で',
#   '運転',
#   'し',
#   '始め',
#   'た',
#   '。',
#   '書生',
#   'が',
#   '動く',
#   'の',
#   'か',
#   '自分',
#   'だけ',
#   'が',
#   '動く',
#   'の',
#   'か',
#   '分ら',
#   'ない',
#   'が',
#   '無',
#   '暗に',
#   '眼',
#   'が',
#   '廻る',
#   '。',
#   '胸',
#   'が',
#   '悪く',
#   'なる',
#   '。',
#   '到底',
#   '助から',
#   'ない',
#   'と',
#   '思っ',
#   'て',
#   'いる',
#   'と',
#   '、',
#   'ど',
#   'さり',
#   'と',
#   '音',
#   'が',
#   'し',
#   'て',
#   '眼',
#   'から',
#   '火',
#   'が',
#   '出',
#   'た',
#   '。',
#   'それ',
#   'まで',
#   'は',
#   '記憶',
#   'し',
#   'て',
#   'いる',
#   'が',
#   'あと',
#   'は',
#   '何',
#   'の',
#   '事',
#   'やら',
#   'いくら',
#   '考え出そ',
#   'う',
#   'として',
#   'も',
#   '分ら',
#   'ない',
#   '。',
#   'ふと',
#   '気',
#   'が',
#   '付い',
#   'て',
#   '見る',
#   'と',
#   '書生',
#   'は',
#   'い',
#   'ない',
#   '。',
#   'たくさん',
#   'おっ',
#   'た',
#   '兄弟',
#   'が',
#   '一疋',
#   'も',
#   '見え',
#   'ぬ',
#   '。',
#   '肝心',
#   'の',
#   '母親',
#   'さえ',
#   '姿',
#   'を',
#   '隠し',
#   'て',
#   'しまっ',
#   'た',
#   '。',
#   'その',
#   '上今',
#   'まで',
#   'の',
#   '所',
#   'と',
#   'は',
#   '違っ',
#   'て',
#   '無',
#   '暗に',
#   '明るい',
#   '。',
#   '眼',
#   'を',
#   '明い',
#   'て',
#   'い',
#   'られ',
#   'ぬ',
#   'くらい',
#   'だ',
#   '。',
#   'はてな',
#   '何',
#   'でも',
#   '容子',
#   'が',
#   'おかしい',
#   'と',
#   '、',
#   'のそのそ',
#   '這い出し',
#   'て',
#   '見る',
#   'と',
#   '非常',
#   'に',
#   '痛い',
#   '。',
#   '吾輩',
#   'は',
#   '藁',
#   'の',
#   '上',
#   'から',
#   '急',
#   'に',
#   '笹原',
#   'の',
#   '中',
#   'へ',
#   '棄て',
#   'られ',
#   'た',
#   'の',
#   'で',
#   'ある',
#   '。',
#   'ようやく',
#   'の',
#   '思い',
#   'で',
#   '笹原',
#   'を',
#   '這い出す',
#   'と',
#   '向う',
#   'に',
#   '大きな',
#   '池',
#   'が',
#   'ある',
#   '。',
#   '吾輩',
#   'は',
#   '池',
#   'の',
#   '前',
#   'に',
#   '坐っ',
#   'て',
#   'どう',
#   'し',
#   'たら',
#   'よかろ',
#   'う',
#   'と',
#   '考え',
#   'て',
#   '見',
#   'た',
#   '。',
#   '別に',
#   'これ',
#   'という',
#   '分別',
#   'も',
#   '出',
#   'ない',
#   '。',
#   'しばらく',
#   'し',
#   'て',
#   '泣い',
#   'たら',
#   '書生',
#   'が',
#   'また',
#   '迎',
#   'に',
#   '来',
#   'て',
#   'くれる',
#   'か',
#   'と',
#   '考え付い',
#   'た',
#   '。',
#   'ニャー',
#   '、',
#   'ニャー',
#   'と',
#   '試み',
#   'に',
#   'やっ',
#   'て',
#   '見',
#   'た',
#   'が',
#   '誰',
#   'も',
#   '来',
#   'ない',
#   '。',
#   'そのうち',
#   '池',
#   'の',
#   '上',
#   'を',
#   'さらさら',
#   'と',
#   '風',
#   'が',
#   '渡っ',
#   'て',
#   '日',
#   'が',
#   '暮れ',
#   'かかる',
#   '。',
#   '腹',
#   'が',
#   '非常',
#   'に',
#   '減っ',
#   'て',
#   '来',
#   'た',
#   '。',
#   '泣き',
#   'たく',
#   'て',
#   'も',
#   '声',
#   'が',
#   '出',
#   'ない',
#   '。',
#   '仕方',
#   'が',
#   'ない',
#   '、',
#   '何',
#   'で',
#   'も',
#   'よい',
#   'から',
#   '食物',
#   'の',
#   'ある',
#   '所',
#   'まで',
#   'ある',
#   'こう',
#   'と',
#   '決心',
#   'を',
#   'し',
#   'て',
#   'そろ',
#   'り',
#   'そろりと',
#   '池',
#   'を',
#   '左',
#   'り',
#   'に',
#   '廻り',
#   '始め',
#   'た',
#   '。',
#   'どうも',
#   '非常',
#   'に',
#   '苦しい',
#   '。',
#   'そこ',
#   'を',
#   '我慢',
#   'し',
#   'て',
#   '無理やり',
#   'に',
#   '這っ',
#   'て',
#   '行く',
#   'と',
#   'ようやく',
#   'の',
#   '事',
#   'で',
#   '何となく',
#   '人間',
#   '臭い',
#   '所',
#   'へ',
#   '出',
#   'た',
#   '。',
#   'ここ',
#   'へ',
#   '這入っ',
#   'たら',
#   '、',
#   'どうにか',
#   'なる',
#   'と',
#   '思っ',
#   'て',
#   '竹垣',
#   'の',
#   '崩れ',
#   'た',
#   '穴',
#   'から',
#   '、',
#   'とある',
#   '邸',
#   '内',
#   'に',
#   'もぐり込ん',
#   'だ',
#   '。',
#   '縁',
#   'は',
#   '不思議',
#   'な',
#   'もの',
#   'で',
#   '、',
#   'もし',
#   'この',
#   '竹垣',
#   'が',
#   '破れ',
#   'て',
#   'い',
#   'なかっ',
#   'た',
#   'なら',
#   '、',
#   '吾輩',
#   'は',
#   'ついに',
#   '路傍',
#   'に',
#   '餓死',
#   'し',
#   'た',
#   'かも',
#   '知れ',
#   'ん',
#   'の',
#   'で',
#   'ある',
#   '。',
#   '一樹',
#   'の',
#   '蔭',
#   'と',
#   'は',
#   'よく',
#   '云っ',
#   'た',
#   'もの',
#   'だ',
#   '。',
#   'この',
#   '垣根',
#   'の',
#   '穴',
#   'は',
#   '今日',
#   'に',
#   '至る',
#   'まで',
#   '吾輩',
#   'が',
#   '隣家',
#   'の',
#   '三',
#   '毛',
#   'を',
#   '訪問',
#   'する',
#   '時',
#   'の',
#   '通路',
#   'に',
#   'なっ',
#   'て',
#   'いる',
#   '。',
#   'さて',
#   '邸',
#   'へ',
#   'は',
#   '忍び込ん',
#   'だ',
#   'ものの',
#   'これから',
#   '先',
#   'どうして',
#   '善い',
#   'か',
#   '分ら',
#   'ない',
#   '。',
#   'その',
#   'うち',
#   'に',
#   '暗く',
#   'なる',
#   '、',
#   '腹',
#   'は',
#   '減る',
#   '、',
#   '寒',
#   'さ',
#   'は',
#   '寒し',
#   '、',
#   '雨',
#   'が',
#   '降っ',
#   'て',
#   '来る',
#   'という',
#   '始末',
#   'で',
#   'もう',
#   '一刻',
#   'の',
#   '猶予',
#   'が',
#   '出来',
#   'なく',
#   'なっ',
#   'た',
#   '。',
#   '仕方',
#   'が',
#   'ない',
#   'から',
#   'とにかく',
#   '明るく',
#   'て',
#   '暖か',
#   'そう',
#   'な',
#   '方',
#   'へ',
#   '方',
#   'へ',
#   'と',
#   'あるい',
#   'て',
#   '行く',
#   '。',
#   '今',
#   'から',
#   '考える',
#   'と',
#   'その',
#   '時',
#   'は',
#   'すでに',
#   '家',
#   'の',
#   '内',
#   'に',
#   '這入っ',
#   'て',
#   'おっ',
#   'た',
#   'の',
#   'だ',
#   '。',
#   'ここ',
#   'で',
#   '吾輩',
#   'は',
#   '彼',
#   'の',
#   '書生',
#   '以外',
#   'の',
#   '人間',
#   'を',
#   '再び',
#   '見る',
#   'べき',
#   '機会',
#   'に',
#   '遭遇',
#   'し',
#   'た',
#   'の',
#   'で',
#   'ある',
#   '。',
#   '第',
#   '一',
#   'に',
#   '逢っ',
#   'た',
#   'の',
#   'が',
#   'お',
#   'さん',
#   'で',
#   'ある',
#   '。',
#   'これ',
#   'は',
#   '前',
#   'の',
#   '書生',
#   'より',
#   '一層',
#   '乱暴',
#   'な',
#   '方',
#   'で',
#   '吾輩',
#   'を',
#   '見る',
#   'や',
#   '否や',
#   'いきなり',
#   '頸筋',
#   'を',
#   'つかん',
#   'で',
#   '表',
#   'へ',
#   '抛り出し',
#   'た',
#   '。',
#   'いや',
#   'これ',
#   'は',
#   '駄目',
#   'だ',
#   'と',
#   '思っ',
#   'た',
#   'から',
#   '眼',
#   'を',
#   'ねぶっ',
#   'て',
#   '運',
#   'を',
#   '天',
#   'に',
#   '任せ',
#   'て',
#   'い',
#   'た',
#   '。',
#   'しかし',
#   'ひもじい',
#   'の',
#   'と',
#   '寒い',
#   'の',
#   'に',
#   'は',
#   'どうしても',
#   '我慢',
#   'が',
#   '出来',
#   'ん',
#   '。',
#   '吾輩',
#   'は',
#   '再び',
#   'おさん',
#   'の',
#   '隙',
#   'を',
#   '見',
#   'て',
#   '台所',
#   'へ',
#   '這い',
#   '上っ',
#   'た',
#   '。',
#   'すると',
#   '間もなく',
#   'また',
#   '投げ出さ',
#   'れ',
#   'た',
#   '。',
#   '吾輩',
#   'は',
#   '投げ出さ',
#   'れ',
#   'て',
#   'は',
#   '這い',
#   '上り',
#   '、',
#   '這い',
#   '上っ',
#   'て',
#   'は',
#   '投げ出さ',
#   'れ',
#   '、',
#   '何',
#   'でも',
#   '同じ',
#   '事',
#   'を',
#   '四',
#   '五',
#   '遍',
#   '繰り返し',
#   'た',
#   'の',
#   'を',
#   '記憶',
#   'し',
#   'て',
#   'いる',
#   '。',
#   'その',
#   '時',
#   'に',
#   'おさん',
#   'と',
#   '云う',
#   '者',
#   'は',
#   'つくづく',
#   'いや',
#   'に',
#   'なっ',
#   'た',
#   '。',
#   'この間',
#   'おさん',
#   'の',
#   '三',
#   '馬',
#   'を',
#   '偸',
#   'んで',
#   'この',
#   '返報',
#   'を',
#   'し',
#   'て',
#   'やっ',
#   'て',
#   ...],
#  'base': ['*',
#   '*',
#   '*',
#   '*',
#   '特殊・ダ',
#   '五段・ラ行アル',
#   '*',
#   '*',
#   '*',
#   '*',
#   '形容詞・アウオ段',
#   '*',
#   '*',
#   '*',
#   '一段',
#   '特殊・タ',
#   '*',
#   '*',
#   '*',
#   '*',
#   '五段・カ行イ音便',
#   '特殊・ヌ',
#   '*',
#   '*',
#   '*',
#   '形容詞・アウオ段',
#   '*',
#   'サ変・スル',
#   '特殊・タ',
#   '*',
#   '*',
#   '*',
#   '五段・カ行イ音便',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   'サ変・スル',
#   '*',
#   '一段',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '一段',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '一段',
#   '特殊・タ',
#   '*',
#   '*',
#   '*',
#   '*',
#   '五段・カ行イ音便',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '特殊・ダ',
#   '*',
#   '特殊・ダ',
#   '五段・ラ行アル',
#   '特殊・タ',
#   '*',
#   '特殊・ダ',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '一段',
#   '*',
#   '一段',
#   '*',
#   '五段・ワ行促音便',
#   '*',
#   '*',
#   '特殊・ダ',
#   '五段・ラ行アル',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '形容詞・アウオ段',
#   '特殊・タ',
#   '*',
#   '*',
#   '形容詞・アウオ段',
#   '*',
#   '五段・ワ行促音便',
#   '特殊・ナイ',
#   '特殊・タ',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '一段',
#   '一段',
#   '*',
#   '*',
#   '*',
#   '一段',
#   '一段',
#   '特殊・タ',
#   '*',
#   '*',
#   '*',
#   'サ変・スル',
#   '特殊・タ',
#   '*',
#   '*',
#   '五段・ラ行',
#   '特殊・タ',
#   '*',
#   '特殊・ダ',
#   '五段・ラ行アル',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '五段・カ行イ音便',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '一段',
#   '特殊・タ',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '一段',
#   '*',
#   '特殊・ダ',
#   '五段・ラ行アル',
#   '不変化型',
#   '*',
#   '*',
#   '*',
#   '*',
#   '特殊・ダ',
#   '*',
#   '特殊・ダ',
#   '*',
#   '五段・ワ行促音便',
#   '特殊・タ',
#   '*',
#   '*',
#   '*',
#   '*',
#   '五段・ラ行',
#   '*',
#   '一段',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   'サ変・スル',
#   '一段',
#   '文語・ベシ',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   'サ変・スル',
#   '*',
#   '*',
#   '*',
#   '特殊・ダ',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '五段・ワ行促音便',
#   '特殊・タ',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '五段・ワ行促音便',
#   'サ変・スル',
#   '特殊・タ',
#   '*',
#   '*',
#   '形容詞・アウオ段',
#   '*',
#   '五段・マ行',
#   '五段・ラ行',
#   '特殊・ヌ',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   'サ変・スル',
#   '*',
#   '一段',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '五段・カ行イ音便',
#   '*',
#   '*',
#   '*',
#   'サ変・スル',
#   '形容詞・アウオ段',
#   '*',
#   '*',
#   '五段・ラ行',
#   '特殊・タ',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '五段・マ行',
#   '*',
#   '*',
#   '*',
#   '特殊・ダ',
#   '五段・ラ行アル',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '五段・ラ行',
#   '特殊・タ',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '形容詞・アウオ段',
#   '*',
#   '*',
#   '五段・ラ行',
#   '*',
#   '五段・ラ行',
#   '特殊・タ',
#   '*',
#   '*',
#   '*',
#   'サ変・スル',
#   '*',
#   '*',
#   '特殊・ダ',
#   '*',
#   '*',
#   '*',
#   'サ変・スル',
#   '一段',
#   '特殊・タ',
#   '*',
#   '*',
#   '*',
#   '五段・カ行イ音便',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '五段・カ行イ音便',
#   '*',
#   '*',
#   '五段・ラ行',
#   '特殊・ナイ',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '五段・ラ行',
#   '*',
#   '*',
#   '*',
#   '形容詞・アウオ段',
#   '五段・ラ行',
#   '*',
#   '*',
#   '五段・ラ行',
#   '特殊・ナイ',
#   '*',
#   '五段・ワ行促音便',
#   '*',
#   '一段',
#   '*',
#   '*',
#   '*',
#   '五段・ラ行',
#   '*',
#   '*',
#   '*',
#   'サ変・スル',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '一段',
#   '特殊・タ',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   'サ変・スル',
#   '*',
#   '一段',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '五段・サ行',
#   '不変化型',
#   '*',
#   '*',
#   '五段・ラ行',
#   '特殊・ナイ',
#   '*',
#   '*',
#   '*',
#   '*',
#   '五段・カ行イ音便',
#   '*',
#   '一段',
#   '*',
#   '*',
#   '*',
#   '一段',
#   '特殊・ナイ',
#   '*',
#   '*',
#   '五段・ラ行',
#   '特殊・タ',
#   '*',
#   '*',
#   '*',
#   '*',
#   '一段',
#   '特殊・ヌ',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '五段・サ行',
#   '*',
#   '五段・ワ行促音便',
#   '特殊・タ',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '五段・ワ行促音便',
#   '*',
#   '*',
#   '*',
#   '形容詞・アウオ段',
#   '*',
#   '*',
#   '*',
#   '五段・カ行イ音便',
#   '*',
#   '一段',
#   '一段',
#   '特殊・ヌ',
#   '*',
#   '特殊・ダ',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '形容詞・イ段',
#   '*',
#   '*',
#   '*',
#   '五段・サ行',
#   '*',
#   '一段',
#   '*',
#   '*',
#   '*',
#   '形容詞・アウオ段',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '一段',
#   '一段',
#   '特殊・タ',
#   '*',
#   '特殊・ダ',
#   '五段・ラ行アル',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '五段・サ行',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '五段・ラ行',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '五段・ラ行',
#   '*',
#   '*',
#   'サ変・スル',
#   '特殊・タ',
#   '形容詞・アウオ段',
#   '不変化型',
#   '*',
#   '一段',
#   '*',
#   '一段',
#   '特殊・タ',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '一段',
#   '特殊・ナイ',
#   '*',
#   '*',
#   'サ変・スル',
#   '*',
#   '五段・カ行イ音便',
#   '特殊・タ',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   'カ変・来ル',
#   '*',
#   '一段・クレル',
#   '*',
#   '*',
#   '五段・カ行イ音便',
#   '特殊・タ',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '五段・ラ行',
#   '*',
#   '一段',
#   '特殊・タ',
#   '*',
#   '*',
#   '*',
#   'カ変・来ル',
#   '特殊・ナイ',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '五段・ラ行',
#   '*',
#   '*',
#   '*',
#   '*',
#   '五段・ラ行',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '五段・ラ行',
#   '*',
#   'カ変・来ル',
#   '特殊・タ',
#   '*',
#   '五段・カ行イ音便',
#   '特殊・タイ',
#   '*',
#   '*',
#   '*',
#   '*',
#   '一段',
#   '特殊・ナイ',
#   '*',
#   '*',
#   '*',
#   '形容詞・アウオ段',
#   '*',
#   '*',
#   '*',
#   '*',
#   '形容詞・アウオ段',
#   '*',
#   '*',
#   '*',
#   '五段・ラ行',
#   '*',
#   '*',
#   '五段・ラ行',
#   '*',
#   '*',
#   '*',
#   '*',
#   'サ変・スル',
#   '*',
#   '五段・ラ行',
#   '文語・リ',
#   '*',
#   '*',
#   '*',
#   '*',
#   '文語・リ',
#   '*',
#   '五段・ラ行',
#   '一段',
#   '特殊・タ',
#   '*',
#   '*',
#   '*',
#   '*',
#   '形容詞・イ段',
#   '*',
#   '*',
#   '*',
#   '*',
#   'サ変・スル',
#   '*',
#   '*',
#   '*',
#   '五段・ワ行促音便',
#   '*',
#   '五段・カ行促音便',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '形容詞・アウオ段',
#   '*',
#   '*',
#   '一段',
#   '特殊・タ',
#   '*',
#   '*',
#   '*',
#   '五段・ラ行',
#   '特殊・タ',
#   '*',
#   '*',
#   '五段・ラ行',
#   '*',
#   '五段・ワ行促音便',
#   '*',
#   '*',
#   '*',
#   '一段',
#   '特殊・タ',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '五段・マ行',
#   '特殊・タ',
#   '*',
#   '*',
#   '*',
#   '*',
#   '特殊・ダ',
#   '*',
#   '特殊・ダ',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '一段',
#   '*',
#   '一段',
#   '特殊・ナイ',
#   '特殊・タ',
#   '特殊・ダ',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   'サ変・スル',
#   '特殊・タ',
#   '*',
#   '一段',
#   '不変化型',
#   '*',
#   '特殊・ダ',
#   '五段・ラ行アル',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '五段・ワ行促音便',
#   '特殊・タ',
#   '*',
#   '特殊・ダ',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '五段・ラ行',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   'サ変・スル',
#   '*',
#   '*',
#   '*',
#   '*',
#   '五段・ラ行',
#   '*',
#   '一段',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '五段・マ行',
#   '特殊・タ',
#   '*',
#   '*',
#   '*',
#   '*',
#   '形容詞・アウオ段',
#   '*',
#   '五段・ラ行',
#   '特殊・ナイ',
#   '*',
#   '*',
#   '*',
#   '*',
#   '形容詞・アウオ段',
#   '五段・ラ行',
#   '*',
#   '*',
#   '*',
#   '五段・ラ行',
#   '*',
#   '形容詞・アウオ段',
#   '*',
#   '*',
#   '形容詞・アウオ段',
#   '*',
#   '*',
#   '*',
#   '五段・ラ行',
#   '*',
#   'カ変・来ル',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '一段',
#   '特殊・ナイ',
#   '五段・ラ行',
#   '特殊・タ',
#   '*',
#   '*',
#   '*',
#   '形容詞・アウオ段',
#   '*',
#   '*',
#   '形容詞・アウオ段',
#   '*',
#   '形容詞・アウオ段',
#   '*',
#   '特殊・ダ',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '五段・カ行イ音便',
#   '*',
#   '五段・カ行促音便',
#   '*',
#   '*',
#   '*',
#   '一段',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '五段・ラ行',
#   '*',
#   '五段・ラ行',
#   '特殊・タ',
#   '*',
#   '特殊・ダ',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '一段',
#   '文語・ベシ',
#   '*',
#   '*',
#   '*',
#   'サ変・スル',
#   '特殊・タ',
#   '*',
#   '特殊・ダ',
#   '五段・ラ行アル',
#   '*',
#   '*',
#   '*',
#   '*',
#   '五段・ワ行促音便',
#   '特殊・タ',
#   '*',
#   '*',
#   '*',
#   '*',
#   '特殊・ダ',
#   '五段・ラ行アル',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '特殊・ダ',
#   '*',
#   '*',
#   '*',
#   '*',
#   '一段',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '五段・マ行',
#   '*',
#   '*',
#   '*',
#   '五段・サ行',
#   '特殊・タ',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '特殊・ダ',
#   '*',
#   '五段・ワ行促音便',
#   '特殊・タ',
#   '*',
#   '*',
#   '*',
#   '五段・ラ行',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '一段',
#   '*',
#   '一段',
#   '特殊・タ',
#   '*',
#   '*',
#   '形容詞・イ段',
#   '*',
#   '*',
#   '形容詞・アウオ段',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '一段',
#   '不変化型',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '一段',
#   '*',
#   '*',
#   '*',
#   '五段・ワ行促音便',
#   '五段・ラ行',
#   '特殊・タ',
#   '*',
#   '*',
#   '*',
#   '*',
#   '五段・サ行',
#   '一段',
#   '特殊・タ',
#   '*',
#   '*',
#   '*',
#   '五段・サ行',
#   '一段',
#   '*',
#   '*',
#   '五段・ワ行促音便',
#   '五段・ラ行',
#   '*',
#   '五段・ワ行促音便',
#   '五段・ラ行',
#   '*',
#   '*',
#   '五段・サ行',
#   '一段',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '五段・サ行',
#   '特殊・タ',
#   '*',
#   '*',
#   '*',
#   'サ変・スル',
#   '*',
#   '一段',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '五段・ワ行促音便',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '五段・ラ行',
#   '特殊・タ',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   'サ変・スル',
#   '*',
#   '五段・ラ行',
#   '*',
#   ...],
#  'pos': ['名詞',
#   '名詞',
#   '助詞',
#   '名詞',
#   '助動詞',
#   '助動詞',
#   '記号',
#   '名詞',
#   '助詞',
#   '副詞',
#   '形容詞',
#   '記号',
#   '名詞',
#   '助詞',
#   '動詞',
#   '助動詞',
#   '助詞',
#   '副詞',
#   '名詞',
#   '助詞',
#   '動詞',
#   '助動詞',
#   '記号',
#   '名詞',
#   '助詞',
#   '形容詞',
#   '副詞',
#   '動詞',
#   '助動詞',
#   '名詞',
#   '助詞',
#   '名詞',
#   '動詞',
#   '助詞',
#   '名詞',
#   '助詞',
#   '助詞',
#   '名詞',
#   '動詞',
#   '助詞',
#   '動詞',
#   '記号',
#   '名詞',
#   '助詞',
#   '名詞',
#   '助詞',
#   '動詞',
#   '助詞',
#   '名詞',
#   '助詞',
#   '名詞',
#   '助詞',
#   '動詞',
#   '助動詞',
#   '記号',
#   '接続詞',
#   '名詞',
#   '助詞',
#   '動詞',
#   '助詞',
#   '名詞',
#   '助詞',
#   '名詞',
#   '助詞',
#   '名詞',
#   '名詞',
#   '助詞',
#   '名詞',
#   '名詞',
#   '助動詞',
#   '名詞',
#   '助動詞',
#   '助動詞',
#   '助動詞',
#   '名詞',
#   '助動詞',
#   '記号',
#   '連体詞',
#   '名詞',
#   '助詞',
#   '名詞',
#   '助詞',
#   '副詞',
#   '名詞',
#   '助詞',
#   '動詞',
#   '助詞',
#   '動詞',
#   '助詞',
#   '動詞',
#   '助詞',
#   '名詞',
#   '助動詞',
#   '助動詞',
#   '記号',
#   '接続詞',
#   '連体詞',
#   '名詞',
#   '助詞',
#   '名詞',
#   '助詞',
#   '名詞',
#   '助詞',
#   '形容詞',
#   '助動詞',
#   '助詞',
#   '副詞',
#   '形容詞',
#   '副詞',
#   '動詞',
#   '助動詞',
#   '助動詞',
#   '記号',
#   '接続詞',
#   '名詞',
#   '助詞',
#   '名詞',
#   '助詞',
#   '動詞',
#   '動詞',
#   '助詞',
#   '名詞',
#   '助詞',
#   '動詞',
#   '動詞',
#   '助動詞',
#   '名詞',
#   '副詞',
#   '副詞',
#   '動詞',
#   '助動詞',
#   '名詞',
#   '助詞',
#   '動詞',
#   '助動詞',
#   '助詞',
#   '助動詞',
#   '助動詞',
#   '記号',
#   '名詞',
#   '助詞',
#   '名詞',
#   '助詞',
#   '副詞',
#   '動詞',
#   '助詞',
#   '名詞',
#   '助詞',
#   '名詞',
#   '助詞',
#   '動詞',
#   '助動詞',
#   '名詞',
#   '助詞',
#   '連体詞',
#   '名詞',
#   '助詞',
#   '名詞',
#   '助詞',
#   '動詞',
#   '名詞',
#   '助動詞',
#   '助動詞',
#   '助動詞',
#   '記号',
#   '連体詞',
#   '名詞',
#   '名詞',
#   '助動詞',
#   '名詞',
#   '助動詞',
#   '助詞',
#   '動詞',
#   '助動詞',
#   '名詞',
#   '助詞',
#   '名詞',
#   '助詞',
#   '動詞',
#   '助詞',
#   '動詞',
#   '記号',
#   '接頭詞',
#   '名詞',
#   '名詞',
#   '助詞',
#   '名詞',
#   '動詞',
#   '動詞',
#   '助動詞',
#   '名詞',
#   '助詞',
#   '名詞',
#   '助詞',
#   '副詞',
#   '動詞',
#   '助詞',
#   '副詞',
#   '名詞',
#   '助動詞',
#   '記号',
#   '名詞',
#   '名詞',
#   '助詞',
#   '助詞',
#   '副詞',
#   '動詞',
#   '助動詞',
#   '助詞',
#   '連体詞',
#   '接頭詞',
#   '名詞',
#   '助詞',
#   '助詞',
#   '名詞',
#   '名詞',
#   '助詞',
#   '動詞',
#   '動詞',
#   '助動詞',
#   '名詞',
#   '助詞',
#   '形容詞',
#   '記号',
#   '動詞',
#   '動詞',
#   '助動詞',
#   '名詞',
#   '助詞',
#   '名詞',
#   '助詞',
#   '副詞',
#   '名詞',
#   '動詞',
#   '助詞',
#   '動詞',
#   '記号',
#   '接続詞',
#   '連体詞',
#   '名詞',
#   '助詞',
#   '名詞',
#   '助詞',
#   '副詞',
#   '名詞',
#   '名詞',
#   '助詞',
#   '動詞',
#   '記号',
#   '副詞',
#   '名詞',
#   '動詞',
#   '形容詞',
#   '助詞',
#   '副詞',
#   '動詞',
#   '助動詞',
#   '記号',
#   '名詞',
#   '助詞',
#   '名詞',
#   '助詞',
#   '動詞',
#   '名詞',
#   '助詞',
#   '名詞',
#   '助動詞',
#   '助動詞',
#   '名詞',
#   '助詞',
#   '副詞',
#   '連体詞',
#   '名詞',
#   '動詞',
#   '助動詞',
#   '記号',
#   '連体詞',
#   '名詞',
#   '助詞',
#   '名詞',
#   '助詞',
#   '名詞',
#   '助詞',
#   '副詞',
#   '助詞',
#   '形容詞',
#   '名詞',
#   '助詞',
#   '動詞',
#   '助詞',
#   '動詞',
#   '助動詞',
#   '助詞',
#   '記号',
#   '副詞',
#   '動詞',
#   '助詞',
#   '名詞',
#   '助動詞',
#   '名詞',
#   '助詞',
#   '名詞',
#   '動詞',
#   '動詞',
#   '助動詞',
#   '記号',
#   '名詞',
#   '助詞',
#   '動詞',
#   '名詞',
#   '助詞',
#   '名詞',
#   '助詞',
#   '助詞',
#   '動詞',
#   '名詞',
#   '助詞',
#   '動詞',
#   '助動詞',
#   '助詞',
#   '接頭詞',
#   '副詞',
#   '名詞',
#   '助詞',
#   '動詞',
#   '記号',
#   '名詞',
#   '助詞',
#   '形容詞',
#   '動詞',
#   '記号',
#   '副詞',
#   '動詞',
#   '助動詞',
#   '助詞',
#   '動詞',
#   '助詞',
#   '動詞',
#   '助詞',
#   '記号',
#   '接頭詞',
#   '動詞',
#   '助詞',
#   '名詞',
#   '助詞',
#   '動詞',
#   '助詞',
#   '名詞',
#   '助詞',
#   '名詞',
#   '助詞',
#   '動詞',
#   '助動詞',
#   '記号',
#   '名詞',
#   '助詞',
#   '助詞',
#   '名詞',
#   '動詞',
#   '助詞',
#   '動詞',
#   '助詞',
#   '名詞',
#   '助詞',
#   '名詞',
#   '助詞',
#   '名詞',
#   '助詞',
#   '副詞',
#   '動詞',
#   '助動詞',
#   '助詞',
#   '助詞',
#   '動詞',
#   '助動詞',
#   '記号',
#   '副詞',
#   '名詞',
#   '助詞',
#   '動詞',
#   '助詞',
#   '動詞',
#   '助詞',
#   '名詞',
#   '助詞',
#   '動詞',
#   '助動詞',
#   '記号',
#   '名詞',
#   '動詞',
#   '助動詞',
#   '名詞',
#   '助詞',
#   '名詞',
#   '助詞',
#   '動詞',
#   '助動詞',
#   '記号',
#   '名詞',
#   '助詞',
#   '名詞',
#   '助詞',
#   '名詞',
#   '助詞',
#   '動詞',
#   '助詞',
#   '動詞',
#   '助動詞',
#   '記号',
#   '連体詞',
#   '名詞',
#   '助詞',
#   '助詞',
#   '名詞',
#   '助詞',
#   '助詞',
#   '動詞',
#   '助詞',
#   '接頭詞',
#   '副詞',
#   '形容詞',
#   '記号',
#   '名詞',
#   '助詞',
#   '動詞',
#   '助詞',
#   '動詞',
#   '動詞',
#   '助動詞',
#   '助詞',
#   '助動詞',
#   '記号',
#   '感動詞',
#   '名詞',
#   '助詞',
#   '名詞',
#   '助詞',
#   '形容詞',
#   '助詞',
#   '記号',
#   '副詞',
#   '動詞',
#   '助詞',
#   '動詞',
#   '助詞',
#   '名詞',
#   '助詞',
#   '形容詞',
#   '記号',
#   '名詞',
#   '助詞',
#   '名詞',
#   '助詞',
#   '名詞',
#   '助詞',
#   '名詞',
#   '助詞',
#   '名詞',
#   '助詞',
#   '名詞',
#   '助詞',
#   '動詞',
#   '動詞',
#   '助動詞',
#   '名詞',
#   '助動詞',
#   '助動詞',
#   '記号',
#   '副詞',
#   '助詞',
#   '名詞',
#   '助詞',
#   '名詞',
#   '助詞',
#   '動詞',
#   '助詞',
#   '名詞',
#   '助詞',
#   '連体詞',
#   '名詞',
#   '助詞',
#   '動詞',
#   '記号',
#   '名詞',
#   '助詞',
#   '名詞',
#   '助詞',
#   '名詞',
#   '助詞',
#   '動詞',
#   '助詞',
#   '副詞',
#   '動詞',
#   '助動詞',
#   '形容詞',
#   '助動詞',
#   '助詞',
#   '動詞',
#   '助詞',
#   '動詞',
#   '助動詞',
#   '記号',
#   '副詞',
#   '名詞',
#   '助詞',
#   '名詞',
#   '助詞',
#   '動詞',
#   '助動詞',
#   '記号',
#   '副詞',
#   '動詞',
#   '助詞',
#   '動詞',
#   '助動詞',
#   '名詞',
#   '助詞',
#   '接続詞',
#   '名詞',
#   '助詞',
#   '動詞',
#   '助詞',
#   '動詞',
#   '助詞',
#   '助詞',
#   '動詞',
#   '助動詞',
#   '記号',
#   '名詞',
#   '記号',
#   '名詞',
#   '助詞',
#   '名詞',
#   '助詞',
#   '動詞',
#   '助詞',
#   '動詞',
#   '助動詞',
#   '助詞',
#   '名詞',
#   '助詞',
#   '動詞',
#   '助動詞',
#   '記号',
#   '副詞',
#   '名詞',
#   '助詞',
#   '名詞',
#   '助詞',
#   '副詞',
#   '助詞',
#   '名詞',
#   '助詞',
#   '動詞',
#   '助詞',
#   '名詞',
#   '助詞',
#   '名詞',
#   '動詞',
#   '記号',
#   '名詞',
#   '助詞',
#   '名詞',
#   '助詞',
#   '動詞',
#   '助詞',
#   '動詞',
#   '助動詞',
#   '記号',
#   '動詞',
#   '助動詞',
#   '助詞',
#   '助詞',
#   '名詞',
#   '助詞',
#   '動詞',
#   '助動詞',
#   '記号',
#   '名詞',
#   '助詞',
#   '形容詞',
#   '記号',
#   '名詞',
#   '助詞',
#   '助詞',
#   '形容詞',
#   '助詞',
#   '名詞',
#   '助詞',
#   '動詞',
#   '名詞',
#   '助詞',
#   '動詞',
#   '副詞',
#   '助詞',
#   '名詞',
#   '助詞',
#   '動詞',
#   '助詞',
#   '動詞',
#   '助動詞',
#   '副詞',
#   '名詞',
#   '助詞',
#   '名詞',
#   '助動詞',
#   '助詞',
#   '動詞',
#   '動詞',
#   '助動詞',
#   '記号',
#   '副詞',
#   '名詞',
#   '助詞',
#   '形容詞',
#   '記号',
#   '名詞',
#   '助詞',
#   '名詞',
#   '動詞',
#   '助詞',
#   '名詞',
#   '助詞',
#   '動詞',
#   '助詞',
#   '動詞',
#   '助詞',
#   '副詞',
#   '助詞',
#   '名詞',
#   '助詞',
#   '副詞',
#   '名詞',
#   '形容詞',
#   '名詞',
#   '助詞',
#   '動詞',
#   '助動詞',
#   '記号',
#   '名詞',
#   '助詞',
#   '動詞',
#   '助動詞',
#   '記号',
#   '副詞',
#   '動詞',
#   '助詞',
#   '動詞',
#   '助詞',
#   '名詞',
#   '助詞',
#   '動詞',
#   '助動詞',
#   '名詞',
#   '助詞',
#   '記号',
#   '連体詞',
#   '名詞',
#   '名詞',
#   '助詞',
#   '動詞',
#   '助動詞',
#   '記号',
#   '名詞',
#   '助詞',
#   '名詞',
#   '助動詞',
#   '名詞',
#   '助動詞',
#   '記号',
#   '副詞',
#   '連体詞',
#   '名詞',
#   '助詞',
#   '動詞',
#   '助詞',
#   '動詞',
#   '助動詞',
#   '助動詞',
#   '助動詞',
#   '記号',
#   '名詞',
#   '助詞',
#   '副詞',
#   '名詞',
#   '助詞',
#   '名詞',
#   '動詞',
#   '助動詞',
#   '助詞',
#   '動詞',
#   '助動詞',
#   '名詞',
#   '助動詞',
#   '助動詞',
#   '記号',
#   '名詞',
#   '助詞',
#   '名詞',
#   '助詞',
#   '助詞',
#   '副詞',
#   '動詞',
#   '助動詞',
#   '名詞',
#   '助動詞',
#   '記号',
#   '連体詞',
#   '名詞',
#   '助詞',
#   '名詞',
#   '助詞',
#   '名詞',
#   '助詞',
#   '動詞',
#   '助詞',
#   '名詞',
#   '助詞',
#   '名詞',
#   '助詞',
#   '名詞',
#   '名詞',
#   '助詞',
#   '名詞',
#   '動詞',
#   '名詞',
#   '助詞',
#   '名詞',
#   '助詞',
#   '動詞',
#   '助詞',
#   '動詞',
#   '記号',
#   '接続詞',
#   '名詞',
#   '助詞',
#   '助詞',
#   '動詞',
#   '助動詞',
#   '助詞',
#   '副詞',
#   '名詞',
#   '副詞',
#   '形容詞',
#   '助詞',
#   '動詞',
#   '助動詞',
#   '記号',
#   '連体詞',
#   '名詞',
#   '助詞',
#   '形容詞',
#   '動詞',
#   '記号',
#   '名詞',
#   '助詞',
#   '動詞',
#   '記号',
#   '形容詞',
#   '名詞',
#   '助詞',
#   '形容詞',
#   '記号',
#   '名詞',
#   '助詞',
#   '動詞',
#   '助詞',
#   '動詞',
#   '助詞',
#   '名詞',
#   '助詞',
#   '副詞',
#   '名詞',
#   '助詞',
#   '名詞',
#   '助詞',
#   '動詞',
#   '助動詞',
#   '動詞',
#   '助動詞',
#   '記号',
#   '名詞',
#   '助詞',
#   '形容詞',
#   '助詞',
#   '副詞',
#   '形容詞',
#   '助詞',
#   '形容詞',
#   '名詞',
#   '助動詞',
#   '名詞',
#   '助詞',
#   '名詞',
#   '助詞',
#   '助詞',
#   '動詞',
#   '助詞',
#   '動詞',
#   '記号',
#   '名詞',
#   '助詞',
#   '動詞',
#   '助詞',
#   '連体詞',
#   '名詞',
#   '助詞',
#   '副詞',
#   '名詞',
#   '助詞',
#   '名詞',
#   '助詞',
#   '動詞',
#   '助詞',
#   '動詞',
#   '助動詞',
#   '名詞',
#   '助動詞',
#   '記号',
#   '名詞',
#   '助詞',
#   '名詞',
#   '助詞',
#   '名詞',
#   '助詞',
#   '名詞',
#   '名詞',
#   '助詞',
#   '名詞',
#   '助詞',
#   '副詞',
#   '動詞',
#   '助動詞',
#   '名詞',
#   '助詞',
#   '名詞',
#   '動詞',
#   '助動詞',
#   '名詞',
#   '助動詞',
#   '助動詞',
#   '記号',
#   '接頭詞',
#   '名詞',
#   '助詞',
#   '動詞',
#   '助動詞',
#   '名詞',
#   '助詞',
#   '接頭詞',
#   '名詞',
#   '助動詞',
#   '助動詞',
#   '記号',
#   '名詞',
#   '助詞',
#   '名詞',
#   '助詞',
#   '名詞',
#   '助詞',
#   '副詞',
#   '名詞',
#   '助動詞',
#   '名詞',
#   '助詞',
#   '名詞',
#   '助詞',
#   '動詞',
#   '助詞',
#   '名詞',
#   '副詞',
#   '名詞',
#   '助詞',
#   '動詞',
#   '助詞',
#   '名詞',
#   '助詞',
#   '動詞',
#   '助動詞',
#   '記号',
#   '接続詞',
#   '名詞',
#   '助詞',
#   '名詞',
#   '助動詞',
#   '助詞',
#   '動詞',
#   '助動詞',
#   '助詞',
#   '名詞',
#   '助詞',
#   '動詞',
#   '助詞',
#   '名詞',
#   '助詞',
#   '名詞',
#   '助詞',
#   '動詞',
#   '助詞',
#   '動詞',
#   '助動詞',
#   '記号',
#   '接続詞',
#   '形容詞',
#   '名詞',
#   '助詞',
#   '形容詞',
#   '名詞',
#   '助詞',
#   '助詞',
#   '副詞',
#   '名詞',
#   '助詞',
#   '動詞',
#   '助動詞',
#   '記号',
#   '名詞',
#   '助詞',
#   '副詞',
#   '名詞',
#   '助詞',
#   '名詞',
#   '助詞',
#   '動詞',
#   '助詞',
#   '名詞',
#   '助詞',
#   '動詞',
#   '動詞',
#   '助動詞',
#   '記号',
#   '接続詞',
#   '副詞',
#   '副詞',
#   '動詞',
#   '動詞',
#   '助動詞',
#   '記号',
#   '名詞',
#   '助詞',
#   '動詞',
#   '動詞',
#   '助詞',
#   '助詞',
#   '動詞',
#   '動詞',
#   '記号',
#   '動詞',
#   '動詞',
#   '助詞',
#   '助詞',
#   '動詞',
#   '動詞',
#   '記号',
#   '名詞',
#   '助詞',
#   '連体詞',
#   '名詞',
#   '助詞',
#   '名詞',
#   '名詞',
#   '名詞',
#   '動詞',
#   '助動詞',
#   '名詞',
#   '助詞',
#   '名詞',
#   '動詞',
#   '助詞',
#   '動詞',
#   '記号',
#   '連体詞',
#   '名詞',
#   '助詞',
#   '名詞',
#   '助詞',
#   '動詞',
#   '名詞',
#   '助詞',
#   '副詞',
#   '名詞',
#   '助詞',
#   '動詞',
#   '助動詞',
#   '記号',
#   '名詞',
#   '名詞',
#   '助詞',
#   '名詞',
#   '名詞',
#   '助詞',
#   '名詞',
#   '助詞',
#   '連体詞',
#   '名詞',
#   '助詞',
#   '動詞',
#   '助詞',
#   '動詞',
#   '助詞',
#   ...],
#  'pos1': ['数',
#   '代名詞',
#   '係助詞',
#   '一般',
#   '*',
#   '*',
#   '句点',
#   '一般',
#   '係助詞',
#   '助詞類接続',
#   '自立',
#   '句点',
#   '代名詞',
#   '格助詞',
#   '自立',
#   '*',
#   '副助詞／並立助詞／終助詞',
#   '一般',
#   'サ変接続',
#   '格助詞',
#   '自立',
#   '*',
#   '句点',
#   '代名詞',
#   '副助詞',
#   '自立',
#   '一般',
#   '自立',
#   '*',
#   '非自立',
#   '格助詞',
#   '一般',
#   '自立',
#   '接続助詞',
#   '一般',
#   '副助詞',
#   '係助詞',
#   'サ変接続',
#   '自立',
#   '接続助詞',
#   '非自立',
#   '句点',
#   '代名詞',
#   '係助詞',
#   '代名詞',
#   '格助詞',
#   '自立',
#   '接続助詞',
#   '一般',
#   '格助詞',
#   '非自立',
#   '格助詞',
#   '自立',
#   '*',
#   '句点',
#   '*',
#   '一般',
#   '格助詞',
#   '自立',
#   '接続助詞',
#   '代名詞',
#   '係助詞',
#   '一般',
#   '格助詞',
#   '一般',
#   '接尾',
#   '格助詞',
#   '副詞可能',
#   '形容動詞語幹',
#   '*',
#   '一般',
#   '*',
#   '*',
#   '*',
#   '特殊',
#   '*',
#   '句点',
#   '*',
#   '一般',
#   '格助詞',
#   '非自立',
#   '係助詞',
#   '一般',
#   '代名詞',
#   '格助詞',
#   '自立',
#   '接続助詞',
#   '自立',
#   '接続助詞',
#   '自立',
#   '格助詞',
#   'サ変接続',
#   '*',
#   '*',
#   '句点',
#   '*',
#   '*',
#   '副詞可能',
#   '係助詞',
#   '代名詞',
#   '格助詞',
#   '一般',
#   '係助詞',
#   '自立',
#   '*',
#   '接続助詞',
#   '助詞類接続',
#   '自立',
#   '一般',
#   '自立',
#   '*',
#   '*',
#   '句点',
#   '*',
#   '代名詞',
#   '連体化',
#   '一般',
#   '格助詞',
#   '自立',
#   '接尾',
#   '接続助詞',
#   '固有名詞',
#   '格助詞',
#   '自立',
#   '接尾',
#   '*',
#   '非自立',
#   '一般',
#   '助詞類接続',
#   '自立',
#   '*',
#   '一般',
#   '格助詞',
#   '自立',
#   '*',
#   '副助詞',
#   '*',
#   '*',
#   '句点',
#   '一般',
#   '連体化',
#   '非自立',
#   '格助詞',
#   '助詞類接続',
#   '自立',
#   '接続助詞',
#   '一般',
#   '連体化',
#   '一般',
#   '格助詞',
#   '自立',
#   '*',
#   '非自立',
#   '格助詞',
#   '*',
#   '一般',
#   '格助詞',
#   '非自立',
#   '格助詞',
#   '自立',
#   '固有名詞',
#   '*',
#   '*',
#   '*',
#   '句点',
#   '*',
#   '非自立',
#   '形容動詞語幹',
#   '*',
#   '非自立',
#   '*',
#   '格助詞',
#   '自立',
#   '*',
#   '一般',
#   '格助詞',
#   '副詞可能',
#   '副助詞',
#   '自立',
#   '接続助詞',
#   '非自立',
#   '句点',
#   '数接続',
#   '数',
#   '接尾',
#   '格助詞',
#   'サ変接続',
#   '自立',
#   '接尾',
#   '*',
#   '非自立',
#   '連体化',
#   '一般',
#   '格助詞',
#   '一般',
#   '自立',
#   '接続助詞',
#   '一般',
#   '一般',
#   '*',
#   '句点',
#   '副詞可能',
#   '一般',
#   '格助詞',
#   '係助詞',
#   '一般',
#   '自立',
#   '*',
#   '接続助詞',
#   '*',
#   '名詞接続',
#   '一般',
#   '格助詞',
#   '係助詞',
#   '数',
#   '接尾',
#   '係助詞',
#   '自立',
#   '自立',
#   '*',
#   '非自立',
#   '格助詞',
#   '自立',
#   '句点',
#   '自立',
#   '非自立',
#   '*',
#   '一般',
#   '連体化',
#   '一般',
#   '格助詞',
#   '助詞類接続',
#   'サ変接続',
#   '自立',
#   '接続助詞',
#   '非自立',
#   '句点',
#   '*',
#   '*',
#   '一般',
#   '連体化',
#   '非自立',
#   '格助詞',
#   '一般',
#   '一般',
#   '一般',
#   '格助詞',
#   '自立',
#   '句点',
#   '一般',
#   '一般',
#   '自立',
#   '接尾',
#   '接続助詞',
#   '一般',
#   '自立',
#   '*',
#   '句点',
#   '代名詞',
#   '格助詞',
#   '一般',
#   '格助詞',
#   '自立',
#   '一般',
#   '格助詞',
#   '非自立',
#   '*',
#   '*',
#   '非自立',
#   '係助詞',
#   '一般',
#   '*',
#   '非自立',
#   '自立',
#   '*',
#   '句点',
#   '*',
#   '一般',
#   '連体化',
#   '一般',
#   '連体化',
#   '一般',
#   '格助詞',
#   '助詞類接続',
#   '係助詞',
#   '自立',
#   '一般',
#   '格助詞',
#   '自立',
#   '接続助詞',
#   '自立',
#   '*',
#   '接続助詞',
#   '読点',
#   '助詞類接続',
#   '自立',
#   '接続助詞',
#   '形容動詞語幹',
#   '*',
#   '一般',
#   '格助詞',
#   'サ変接続',
#   '自立',
#   '非自立',
#   '*',
#   '句点',
#   '一般',
#   '格助詞',
#   '自立',
#   '非自立',
#   '副助詞／並立助詞／終助詞',
#   '一般',
#   '副助詞',
#   '格助詞',
#   '自立',
#   '非自立',
#   '副助詞／並立助詞／終助詞',
#   '自立',
#   '*',
#   '接続助詞',
#   '名詞接続',
#   '一般',
#   '一般',
#   '格助詞',
#   '自立',
#   '句点',
#   '一般',
#   '格助詞',
#   '自立',
#   '自立',
#   '句点',
#   '一般',
#   '自立',
#   '*',
#   '格助詞',
#   '自立',
#   '接続助詞',
#   '非自立',
#   '接続助詞',
#   '読点',
#   '名詞接続',
#   '自立',
#   '並立助詞',
#   '一般',
#   '格助詞',
#   '自立',
#   '接続助詞',
#   '一般',
#   '格助詞',
#   '一般',
#   '格助詞',
#   '自立',
#   '*',
#   '句点',
#   '代名詞',
#   '副助詞',
#   '係助詞',
#   'サ変接続',
#   '自立',
#   '接続助詞',
#   '非自立',
#   '接続助詞',
#   '一般',
#   '係助詞',
#   '代名詞',
#   '連体化',
#   '非自立',
#   '終助詞',
#   '一般',
#   '自立',
#   '*',
#   '格助詞',
#   '係助詞',
#   '自立',
#   '*',
#   '句点',
#   '一般',
#   '一般',
#   '格助詞',
#   '自立',
#   '接続助詞',
#   '自立',
#   '接続助詞',
#   '一般',
#   '係助詞',
#   '自立',
#   '*',
#   '句点',
#   '副詞可能',
#   '自立',
#   '*',
#   '一般',
#   '格助詞',
#   '一般',
#   '係助詞',
#   '自立',
#   '*',
#   '句点',
#   '形容動詞語幹',
#   '連体化',
#   '一般',
#   '係助詞',
#   '一般',
#   '格助詞',
#   '自立',
#   '接続助詞',
#   '非自立',
#   '*',
#   '句点',
#   '*',
#   '固有名詞',
#   '副助詞',
#   '連体化',
#   '非自立',
#   '格助詞',
#   '係助詞',
#   '自立',
#   '接続助詞',
#   '名詞接続',
#   '一般',
#   '自立',
#   '句点',
#   '一般',
#   '格助詞',
#   '自立',
#   '接続助詞',
#   '非自立',
#   '接尾',
#   '*',
#   '副助詞',
#   '*',
#   '句点',
#   '*',
#   '代名詞',
#   '副助詞',
#   '一般',
#   '格助詞',
#   '自立',
#   '接続助詞',
#   '読点',
#   '一般',
#   '自立',
#   '接続助詞',
#   '自立',
#   '接続助詞',
#   '形容動詞語幹',
#   '副詞化',
#   '自立',
#   '句点',
#   '代名詞',
#   '係助詞',
#   '一般',
#   '連体化',
#   '非自立',
#   '格助詞',
#   '形容動詞語幹',
#   '副詞化',
#   '一般',
#   '連体化',
#   '非自立',
#   '格助詞',
#   '自立',
#   '接尾',
#   '*',
#   '非自立',
#   '*',
#   '*',
#   '句点',
#   '一般',
#   '連体化',
#   '一般',
#   '格助詞',
#   '一般',
#   '格助詞',
#   '自立',
#   '接続助詞',
#   '一般',
#   '格助詞',
#   '*',
#   '一般',
#   '格助詞',
#   '自立',
#   '句点',
#   '代名詞',
#   '係助詞',
#   '一般',
#   '連体化',
#   '副詞可能',
#   '格助詞',
#   '自立',
#   '接続助詞',
#   '助詞類接続',
#   '自立',
#   '*',
#   '自立',
#   '*',
#   '格助詞',
#   '自立',
#   '接続助詞',
#   '自立',
#   '*',
#   '句点',
#   '一般',
#   '代名詞',
#   '格助詞',
#   'サ変接続',
#   '係助詞',
#   '自立',
#   '*',
#   '句点',
#   '助詞類接続',
#   '自立',
#   '接続助詞',
#   '自立',
#   '*',
#   '一般',
#   '格助詞',
#   '*',
#   '固有名詞',
#   '格助詞',
#   '自立',
#   '接続助詞',
#   '非自立',
#   '副助詞／並立助詞／終助詞',
#   '格助詞',
#   '自立',
#   '*',
#   '句点',
#   '一般',
#   '読点',
#   '一般',
#   '並立助詞',
#   '一般',
#   '格助詞',
#   '自立',
#   '接続助詞',
#   '自立',
#   '*',
#   '接続助詞',
#   '代名詞',
#   '係助詞',
#   '自立',
#   '*',
#   '句点',
#   '一般',
#   '一般',
#   '連体化',
#   '非自立',
#   '格助詞',
#   '一般',
#   '副詞化',
#   '一般',
#   '格助詞',
#   '自立',
#   '接続助詞',
#   '一般',
#   '格助詞',
#   '副詞可能',
#   '自立',
#   '句点',
#   '一般',
#   '格助詞',
#   '形容動詞語幹',
#   '格助詞',
#   '自立',
#   '接続助詞',
#   '非自立',
#   '*',
#   '句点',
#   '自立',
#   '*',
#   '接続助詞',
#   '係助詞',
#   '一般',
#   '格助詞',
#   '自立',
#   '*',
#   '句点',
#   'ナイ形容詞語幹',
#   '格助詞',
#   '自立',
#   '読点',
#   '代名詞',
#   '格助詞',
#   '係助詞',
#   '非自立',
#   '格助詞',
#   '一般',
#   '格助詞',
#   '自立',
#   '非自立',
#   '副助詞',
#   '自立',
#   '助詞類接続',
#   '副詞化',
#   'サ変接続',
#   '格助詞',
#   '自立',
#   '接続助詞',
#   '自立',
#   '*',
#   '一般',
#   '一般',
#   '格助詞',
#   '一般',
#   '*',
#   '格助詞',
#   '自立',
#   '非自立',
#   '*',
#   '句点',
#   '一般',
#   '形容動詞語幹',
#   '副詞化',
#   '自立',
#   '句点',
#   '代名詞',
#   '格助詞',
#   'サ変接続',
#   '自立',
#   '接続助詞',
#   '一般',
#   '格助詞',
#   '自立',
#   '接続助詞',
#   '非自立',
#   '接続助詞',
#   '一般',
#   '連体化',
#   '非自立',
#   '格助詞',
#   '一般',
#   '一般',
#   '自立',
#   '非自立',
#   '格助詞',
#   '自立',
#   '*',
#   '句点',
#   '代名詞',
#   '格助詞',
#   '自立',
#   '*',
#   '読点',
#   '一般',
#   '自立',
#   '格助詞',
#   '自立',
#   '接続助詞',
#   '固有名詞',
#   '連体化',
#   '自立',
#   '*',
#   '一般',
#   '格助詞',
#   '読点',
#   '*',
#   '一般',
#   '接尾',
#   '格助詞',
#   '自立',
#   '*',
#   '句点',
#   '一般',
#   '係助詞',
#   '形容動詞語幹',
#   '*',
#   '非自立',
#   '*',
#   '読点',
#   '一般',
#   '*',
#   '固有名詞',
#   '格助詞',
#   '自立',
#   '接続助詞',
#   '非自立',
#   '*',
#   '*',
#   '*',
#   '読点',
#   '代名詞',
#   '係助詞',
#   '一般',
#   '一般',
#   '格助詞',
#   'サ変接続',
#   '自立',
#   '*',
#   '副助詞',
#   '自立',
#   '*',
#   '非自立',
#   '*',
#   '*',
#   '句点',
#   '一般',
#   '連体化',
#   '一般',
#   '格助詞',
#   '係助詞',
#   '一般',
#   '自立',
#   '*',
#   '非自立',
#   '*',
#   '句点',
#   '*',
#   '一般',
#   '連体化',
#   '一般',
#   '係助詞',
#   '副詞可能',
#   '格助詞',
#   '自立',
#   '副助詞',
#   '代名詞',
#   '格助詞',
#   '一般',
#   '連体化',
#   '数',
#   '接尾',
#   '格助詞',
#   'サ変接続',
#   '自立',
#   '非自立',
#   '連体化',
#   '一般',
#   '格助詞',
#   '自立',
#   '接続助詞',
#   '非自立',
#   '句点',
#   '*',
#   '一般',
#   '格助詞',
#   '係助詞',
#   '自立',
#   '*',
#   '接続助詞',
#   '助詞類接続',
#   '一般',
#   '一般',
#   '自立',
#   '副助詞／並立助詞／終助詞',
#   '自立',
#   '*',
#   '句点',
#   '*',
#   '非自立',
#   '格助詞',
#   '自立',
#   '自立',
#   '読点',
#   '一般',
#   '係助詞',
#   '自立',
#   '読点',
#   '自立',
#   '接尾',
#   '係助詞',
#   '自立',
#   '読点',
#   '一般',
#   '格助詞',
#   '自立',
#   '接続助詞',
#   '非自立',
#   '格助詞',
#   'サ変接続',
#   '格助詞',
#   '一般',
#   '副詞可能',
#   '連体化',
#   'サ変接続',
#   '格助詞',
#   '自立',
#   '*',
#   '自立',
#   '*',
#   '句点',
#   'ナイ形容詞語幹',
#   '格助詞',
#   '自立',
#   '接続助詞',
#   '一般',
#   '自立',
#   '接続助詞',
#   '自立',
#   '接尾',
#   '*',
#   '非自立',
#   '格助詞',
#   '一般',
#   '格助詞',
#   '格助詞',
#   '自立',
#   '接続助詞',
#   '非自立',
#   '句点',
#   '副詞可能',
#   '格助詞',
#   '自立',
#   '接続助詞',
#   '*',
#   '非自立',
#   '係助詞',
#   '一般',
#   '一般',
#   '連体化',
#   '非自立',
#   '格助詞',
#   '自立',
#   '接続助詞',
#   '自立',
#   '*',
#   '非自立',
#   '*',
#   '句点',
#   '代名詞',
#   '格助詞',
#   '代名詞',
#   '係助詞',
#   '代名詞',
#   '連体化',
#   '一般',
#   '非自立',
#   '連体化',
#   '一般',
#   '格助詞',
#   '助詞類接続',
#   '自立',
#   '*',
#   '一般',
#   '格助詞',
#   'サ変接続',
#   '自立',
#   '*',
#   '非自立',
#   '*',
#   '*',
#   '句点',
#   '数接続',
#   '数',
#   '格助詞',
#   '自立',
#   '*',
#   '非自立',
#   '格助詞',
#   '名詞接続',
#   '接尾',
#   '*',
#   '*',
#   '句点',
#   '代名詞',
#   '係助詞',
#   '副詞可能',
#   '連体化',
#   '一般',
#   '格助詞',
#   '助詞類接続',
#   '形容動詞語幹',
#   '*',
#   '非自立',
#   '格助詞',
#   '代名詞',
#   '格助詞',
#   '自立',
#   '接続助詞',
#   '一般',
#   '助詞類接続',
#   '一般',
#   '格助詞',
#   '自立',
#   '接続助詞',
#   '一般',
#   '格助詞',
#   '自立',
#   '*',
#   '句点',
#   '*',
#   '代名詞',
#   '係助詞',
#   '形容動詞語幹',
#   '*',
#   '格助詞',
#   '自立',
#   '*',
#   '接続助詞',
#   '一般',
#   '格助詞',
#   '自立',
#   '接続助詞',
#   '一般',
#   '格助詞',
#   '一般',
#   '格助詞',
#   '自立',
#   '接続助詞',
#   '非自立',
#   '*',
#   '句点',
#   '*',
#   '自立',
#   '非自立',
#   '格助詞',
#   '自立',
#   '非自立',
#   '格助詞',
#   '係助詞',
#   '一般',
#   'サ変接続',
#   '格助詞',
#   '自立',
#   '*',
#   '句点',
#   '代名詞',
#   '係助詞',
#   '助詞類接続',
#   '固有名詞',
#   '連体化',
#   '一般',
#   '格助詞',
#   '自立',
#   '接続助詞',
#   '一般',
#   '格助詞',
#   '自立',
#   '自立',
#   '*',
#   '句点',
#   '*',
#   '助詞類接続',
#   '助詞類接続',
#   '自立',
#   '接尾',
#   '*',
#   '句点',
#   '代名詞',
#   '係助詞',
#   '自立',
#   '接尾',
#   '接続助詞',
#   '係助詞',
#   '自立',
#   '自立',
#   '読点',
#   '自立',
#   '自立',
#   '接続助詞',
#   '係助詞',
#   '自立',
#   '接尾',
#   '読点',
#   '代名詞',
#   '副助詞',
#   '*',
#   '非自立',
#   '格助詞',
#   '数',
#   '数',
#   '接尾',
#   '自立',
#   '*',
#   '非自立',
#   '格助詞',
#   'サ変接続',
#   '自立',
#   '接続助詞',
#   '非自立',
#   '句点',
#   '*',
#   '非自立',
#   '格助詞',
#   '固有名詞',
#   '格助詞',
#   '自立',
#   '非自立',
#   '係助詞',
#   '一般',
#   '形容動詞語幹',
#   '格助詞',
#   '自立',
#   '*',
#   '句点',
#   '副詞可能',
#   '固有名詞',
#   '連体化',
#   '数',
#   '一般',
#   '格助詞',
#   '一般',
#   '接続助詞',
#   '*',
#   'サ変接続',
#   '格助詞',
#   '自立',
#   '接続助詞',
#   '非自立',
#   '接続助詞',
#   ...]}

# %%
data["pos"].str.cat([data["pos1"], data["base"], data["pos1"]], sep=",").values
# Out:
# array(['名詞,数,*,数', '名詞,代名詞,*,代名詞', '助詞,係助詞,*,係助詞', ...,
#        '形容詞,自立,形容詞・アウオ段,自立', '形容詞,自立,形容詞・アウオ段,自立', '記号,句点,*,句点'],
#       dtype=object)

# %% [markdown]
# 31. 動詞
# 動詞の表層形をすべて抽出せよ．

# %% [markdown]
# 32. 動詞の基本形
# 動詞の基本形をすべて抽出せよ．

# %% [markdown]
# 33. 「AのB」
# 2つの名詞が「の」で連結されている名詞句を抽出せよ．

# %% [markdown]
# 34. 名詞の連接
# 名詞の連接（連続して出現する名詞）を最長一致で抽出せよ．

# %% [markdown]
# 35. 単語の出現頻度
# 文章中に出現する単語とその出現頻度を求め，出現頻度の高い順に並べよ．

# %% [markdown]
# 36. 頻度上位10語
# 出現頻度が高い10語とその出現頻度をグラフ（例えば棒グラフなど）で表示せよ．

# %% [markdown]
# 37. 「猫」と共起頻度の高い上位10語
# 「猫」とよく共起する（共起頻度が高い）10語とその出現頻度をグラフ（例えば棒グラフなど）で表示せよ．

# %% [markdown]
# 38. ヒストグラム
# 単語の出現頻度のヒストグラムを描け．ただし，横軸は出現頻度を表し，1から単語の出現頻度の最大値までの線形目盛とする．縦軸はx軸で示される出現頻度となった単語の異なり数（種類数）である．

# %% [markdown]
# 39. Zipfの法則
# 単語の出現頻度順位を横軸，その出現頻度を縦軸として，両対数グラフをプロットせよ．
